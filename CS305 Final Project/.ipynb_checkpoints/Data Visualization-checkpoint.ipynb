# %% [markdown]
# # Data Visualization

# %%
import numpy as np 
import pandas as pd

# %%
DATA = pd.read_csv('clean_data/tracks.csv', skiprows=0, header=0)
DATA = pd.DataFrame(DATA).drop(columns=['id'])

# %%
features = list(DATA.columns)

# %%
DATA = np.array(DATA)

# %%
DATA.shape
# Out:
# (4272, 17)

# %% [markdown]
# ## Featurization
#
# In this step, I will extract each feature.

# %%
def get_features(DATA, features_list):
    features_vals = {}
    for i in range(len(features_list)):
        feature = features_list[i]
        features_vals[feature] = DATA[:,i]
    return features_vals

# %%
features = get_features(DATA, features)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors

plt.hist(features['tempo'], bins=15)
plt.title('2019 Tempo Distribution Hit Songs')
plt.xlabel('tempo')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(features_2018['danceability'], bins=15)
plt.title('2019 Danceability Distribution Hit Songs')
plt.xlabel('danceability')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(features_2018['energy'], bins=15)
plt.title('2019 Energy Distribution Hit Songs')
plt.xlabel('energy')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(features_2018['mode'], bins=2)
plt.title('2019 Mode Distribution Hit Songs')
plt.xlabel('mode')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(features_2018['track_popularity'], bins=15)
plt.title('2019 Song Popularity Distribution Hit Songs')
plt.xlabel('popularity')
plt.ylabel('# of Songs')
plt.show()

# %%
print(features_2018)
plt.hist(features_2018['artist_popularity'], bins=15)
plt.title('2019 Artist Popularity Distribution Hit Songs')
plt.xlabel('popularity')
plt.ylabel('# of Songs')
plt.show()
# Out:
# {'acousticness': array([0.13   , 0.186  , 0.00261, ..., 0.001  , 0.0626 , 0.799  ]), 'danceability': array([0.577, 0.768, 0.762, ..., 0.841, 0.284, 0.834]), 'duration_ms': array([218320., 216897., 209320., ..., 137232., 220589., 150267.]), 'energy': array([0.522, 0.517, 0.7  , ..., 0.695, 0.637, 0.372]), 'instrumentalness': array([9.03e-05, 3.80e-05, 1.56e-05, ..., 4.26e-05, 0.00e+00, 0.00e+00]), 'key': array([5., 7., 9., ..., 9., 9., 1.]), 'liveness': array([0.142, 0.104, 0.153, ..., 0.189, 0.371, 0.275]), 'loudness': array([ -6.594,  -4.323,  -6.021, ...,  -5.625,  -4.893, -11.99 ]), 'mode': array([0., 0., 0., ..., 1., 1., 1.]), 'speechiness': array([0.0984, 0.0312, 0.0694, ..., 0.415 , 0.0486, 0.0358]), 'tempo': array([159.772, 104.992, 116.073, ..., 173.368,  92.045,  96.628]), 'time_signature': array([4., 4., 4., ..., 4., 4., 4.]), 'valence': array([0.119, 0.418, 0.608, ..., 0.408, 0.197, 0.976]), 'track_popularity': array([20., 28., 84., ..., 62., 71., 78.]), 'artist_popularity': array([94.5       , 94.        , 91.        , ..., 89.        ,
#        76.66666667, 69.        ]), 'hit': array([1., 1., 1., ..., 1., 1., 1.])}

# %%
plt.scatter(features_2018['artist_popularity'], features_2018['track_popularity'], c='green', alpha=0.7)
plt.title('Track and Artist Popularity Plot')
plt.xlabel('Artists')
plt.ylabel('Tracks')
plt.show()

# %%
plt.hist(features_2018['liveness'],bins=15)
plt.title('2019 Liveness Distribution Hit Songs')
plt.xlabel('liveness')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(features_2018['speechiness'], bins=15)
plt.title('2019 Speechiness Distribution Hit Songs')
plt.xlabel('speechiness')
plt.ylabel('# of Songs')
plt.show()
