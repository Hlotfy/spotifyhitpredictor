# %% [markdown]
# # Data Visualization

# %%
import numpy as np 
import pandas as pd

# %%
DATA = pd.read_csv('2019_data.csv', skiprows=0, header=0)
DATA = pd.DataFrame(DATA).drop(columns=['id'])
DATA.to_csv('2019_data_no_ids.csv', index=False)
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'track_popularity',
#  'artist_popularity',
#  'year',
#  'hit']

# %%
features = list(DATA.columns)[:-2]

# %%
DATA = np.loadtxt('2019_data_no_ids.csv', delimiter=',', skiprows=1)

# %%
DATA.shape
# Out:
# (1099, 17)

# %% [markdown]
# ## Featurization
#
# In this step, I will extract each feature.

# %%
def get_features(DATA, features_list):
    features_vals = {}
    for i in range(len(features_list)):
        feature = features_list[i]
        features_vals[feature] = DATA[:,i]
    return features_vals

# %%
features_2019 = get_features(DATA, features)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors

plt.hist(tempo, bins=15)
plt.title('2019 Tempo Distribution Hit Songs')
plt.xlabel('tempo')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(danceability, bins=15)
plt.title('2019 Danceability Distribution Hit Songs')
plt.xlabel('danceability')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(energy, bins=15)
plt.title('2019 Energy Distribution Hit Songs')
plt.xlabel('energy')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(mode, bins=3)
plt.title('2019 Mode Distribution Hit Songs')
plt.xlabel('mode')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(track_popularity, bins=15)
plt.title('2019 Song Popularity Distribution Hit Songs')
plt.xlabel('popularity')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(artist_popularity, bins=15)
plt.title('2019 Artist Popularity Distribution Hit Songs')
plt.xlabel('popularity')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.scatter(artist_popularity, track_popularity, c='green', alpha=0.7)
plt.title('Track and Artist Popularity Plot')
plt.xlabel('Artists')
plt.ylabel('Tracks')
plt.show()

# %%
plt.hist(liveness,bins=15)
plt.title('2019 Liveness Distribution Hit Songs')
plt.xlabel('liveness')
plt.ylabel('# of Songs')
plt.show()

# %%
plt.hist(speechiness, bins=15)
plt.title('2019 Speechiness Distribution Hit Songs')
plt.xlabel('speechiness')
plt.ylabel('# of Songs')
plt.show()
